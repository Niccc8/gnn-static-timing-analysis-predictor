# %% [markdown]
# # 🚀 GNN-Based STA Predictor - Training on GPU
#
# This notebook trains your GNN model on Google Colab's free GPU (T4).
#
# **Expected Speedup:** 20-50x faster than CPU (each epoch: 19 min → 20-60 seconds)

# %% [markdown]
# ## 1️⃣ Check GPU Availability

# %%
# Verify GPU is available
# !nvidia-smi
# Out:
# Sat Nov 22 08:26:23 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   57C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# ## 2️⃣ Clone Your Repository

# %%
# Clone your GitHub repo
# !git clone https://github.com/Niccc8/gnn-static-timing-analysis-predictor.git
# %cd gnn-static-timing-analysis-predictor
# Out:
# Cloning into 'gnn-static-timing-analysis-predictor'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 52 (delta 5), reused 51 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (52/52), 107.11 KiB | 1.51 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# /content/gnn-static-timing-analysis-predictor

# %% [markdown]
# ## 3️⃣ Install Dependencies

# %%
# Install required packages
# !pip install torch-geometric pyyaml xgboost loguru tqdm scikit-learn -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 41.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 6.1 MB/s eta 0:00:00

# %% [markdown]
# ## 4️⃣ Upload Your Dataset
#
# **Option A: Upload from Local PC**
# - Zip the `data/processed/timing_predict` folder on your PC
# - Upload the zip file using the cell below
# - Unzip it
#
# **Option B: Use Google Drive**
# - Upload the folder to Google Drive
# - Mount Drive (see cell below)

# %%
# Option A: Upload zip file
from google.colab import files
uploaded = files.upload()  # Select your timing_predict.zip

# Create directory structure first
# !mkdir -p data/processed

# !unzip -q timing_predict.zip -d data/processed/
# !ls data/processed/timing_predict
# Out:
#      <input type="file" id="files-b872cc2e-0f22-4b84-8faf-f329b41c160b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b872cc2e-0f22-4b84-8faf-f329b41c160b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Option B: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Copy dataset from Drive
# !cp -r /content/drive/MyDrive/timing_predict data/processed/
# !ls data/processed/timing_predict

# %% [markdown]
# ## 5️⃣ Start Training with GPU 🔥

# %%
# Train the model with GPU acceleration
# !python src/training/train.py \
  --data_dir data/processed/timing_predict \
  --config experiments/configs/default.yaml \
  --gpu

# %% [markdown]
# ## 6️⃣ Download Trained Model

# %%
# Download the best model checkpoint
from google.colab import files
files.download('experiments/checkpoints/best_model.pth')

# %% [markdown]
# ## 7️⃣ Push Changes Back to GitHub (Optional)

# %%
# If you made changes to the code, push them back
# !git config --global user.name "Your Name"
# !git config --global user.email "your.email@example.com"

# !git add .
# !git commit -m "Trained model on Colab GPU"
# !git push origin main

# %% [markdown]
# ---
#
# ## 📊 Monitor Training (Optional)
#
# If you want to see training curves in real-time:
# 1. Install TensorBoard: `!pip install tensorboard`
# 2. Run: `%load_ext tensorboard`
# 3. View: `%tensorboard --logdir experiments/logs`
